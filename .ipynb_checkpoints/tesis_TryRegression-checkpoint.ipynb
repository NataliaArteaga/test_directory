# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaArteaga/test_directory/blob/master/tesis_TryRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
processDf = pd.read_csv('./processDf.csv')
processDf.head()
fig = plt.figure(figsize=(14,14))
plt.scatter(processDf['Image Number'],processDf['Time Lapse (hr)'])
plt.plot(processDf['Image Number'],processDf['Time Lapse (hr)'])
plt.xlabel('Number of Images')
plt.ylabel('Computational Hours')
plt.grid()
processDf.keys()
nImages = processDf['Image Number'].values.reshape(-1,1)
Hours = processDf['Time Lapse (hr)'].values.reshape(-1,1)
linear_regressor = LinearRegression()
linear_regressor.fit(nImages, Hours)
Hours_pred = linear_regressor.predict(nImages)
Hours_pred
array=([[0.08681818],
       [0.66272727],
       [1.23863636],
       [1.81454545],
       [2.39045455],
       [2.96636364],
       [3.54227273],
       [4.11818182],
       [4.69409091],
       [5.27      ],
       [5.84590909]])
#y=mx+c
m = linear_regressor.coef_[0][0]
c = linear_regressor.intercept_[0]
label = r'$Hours = %0.4f*5 %+0.4f$'%(m,c)
print(label)
Hours = 0.0115*5 -0.4891
fig = plt.figure(figsize=(14,14))
#plt.scatter(processDf['Image Number'],processDf['Time Lapse (hr)'])
plt.plot(processDf['Image Number'],processDf['Time Lapse (hr)'], label='Measured Hours')
plt.plot(nImages, Hours_pred, color='red', label=label)
plt.xlabel('Number of Images')
plt.ylabel('Computational Hours')
plt.legend()
plt.grid()
# Out:
# $Hours = 0.0115*5 -0.4891$

# %%
#importar la libreria de pandas para leer los datos
import pandas as pd
datos = pd.read_csv('./processDfClo.csv')
datos.head()
datos = datos.dropna()
datos.shape
# Out:
# (58, 9)

# %%
import statsmodels.api as sm
from scipy import stats


X = datos.iloc[:,[1,2,3]]
y = datos.CLL

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    CLL   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 9.610e+30
# Date:                Sat, 01 May 2021   Prob (F-statistic):               0.00
# Time:                        03:08:00   Log-Likelihood:                 1750.9
# No. Observations:                  58   AIC:                            -3494.
# Df Residuals:                      54   BIC:                            -3486.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -9.592e-14   1.41e-13     -0.678      0.501    -3.8e-13    1.88e-13
# ...

# %%
import statsmodels.api as sm
from scipy import stats

X = datos.iloc[:,[0,1,2]]
y = datos.CLL

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())



import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
import csv
import pylab as pl

datos = pd.read_csv('./processDfClo.csv')
datos.describe()
cda= datos[['NDVI', 'CVI', 'CLL']]
cda.head(9)
viz=cda[['NDVI', 'CVI', 'CLL']]
viz.hist()
plt.show()

plt.scatter(cda.NDVI,cda.CLL, color='green')
plt.xlabel('NDVI')
plt.ylabel('CLL')
plt.show

plt.scatter(cda.CVI,cda.CLL, color='red')
plt.xlabel('CVI')
plt.ylabel('CLL')
plt.show

msk = np.random.rand(len(datos)) < 0.8
entreno = cda[msk]
test = cda[~msk]

plt.scatter(entreno.CVI,entreno.CLL, color='yellow')
plt.xlabel('CVI')
plt.ylabel('CLL')
plt.show

from sklearn import linear_model
regr = linear_model.LinearRegression ()
entre_x = np.asanyarray(entreno[['NDVI']])
entre_y = np.asanyarray(entreno[['CLL']])

regr.fit(entre_x,entre_y)

print('coeficientes', regr.coef_)
print('interseccion', regr.intercept_)

plt.scatter(entreno.NDVI,entreno.CLL, color='orange')
plt.plot(entre_x,regr.coef_[0][0]*entre_x+regr.intercept_[0], '-r')
plt.xlabel('NDVI')
plt.ylabel('CLL')
plt.show

from sklearn.metrics import r2_score
regr = linear_model.LinearRegression()
test_x = np.asanyarray(test[['NDVI']])
test_y = np.asanyarray(test[['CLL']])
regr.fit(test_x,test_y)
testeo = regr.predict(test_x)

print("Error cuadratico medio: %.2f" % np.mean(np.absolute(testeo - test_y)))
print("Suma de cuadrados residual: %.2f" % np.mean((testeo - test_y) ** 2))
print("R2: %.2f" % r2_score(test_y, testeo))
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    CLL   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 6.066e+30
# Date:                Sat, 01 May 2021   Prob (F-statistic):               0.00
# Time:                        03:08:59   Log-Likelihood:                 1737.6
# No. Observations:                  58   AIC:                            -3467.
# Df Residuals:                      54   BIC:                            -3459.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -9.592e-14   2.96e-14     -3.240      0.002   -1.55e-13   -3.66e-14
# ...
